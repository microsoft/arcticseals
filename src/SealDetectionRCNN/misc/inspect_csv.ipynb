# %%
import csv
import json
import pandas as pd

# %%
csv_path = '/Users/siyuyang/Source/Repos/PlasticFreeOceans/pilot_images_and_annotations/grogol-pilot-classifications.csv'

# %%
csv = pd.read_csv(csv_path)

# %%
csv
# Out:
#     classification_id                           user_name    user_id  \
# 0           116283620                      keesvanoeveren  1802420.0
# 1           116283901                      keesvanoeveren  1802420.0
# 2           116283906                      keesvanoeveren  1802420.0
# 3           116283908                      keesvanoeveren  1802420.0
# 4           116284257                      keesvanoeveren  1802420.0
# 5           116310669  not-logged-in-6331c8a62a607a4736c7        NaN
# 6           116365940  not-logged-in-d20e78910b5f230ee953        NaN
# 7           116365945  not-logged-in-d20e78910b5f230ee953        NaN
# 8           116469559                      keesvanoeveren  1802420.0
# 9           116495879                            cyliesho  1802525.0
# 10          116495891                            cyliesho  1802525.0
# 11          116495917                            cyliesho  1802525.0
# 12          116565125  not-logged-in-dd682b2d6d163d3f56fd        NaN
# ...

# %%
len(csv)
# Out:
# 87

# %%
annotations_0 = json.loads(csv.loc[0, 'annotations'])
annotations_0
# Out:
# [{'task': 'T0', 'task_label': 'Tag plastic and organics', 'value': None}]

# %%
metadata_0 = json.loads(csv.loc[0, 'metadata'])
metadata_0
# Out:
# {'finished_at': '2018-07-06T13:08:06.957Z',
#  'live_project': False,
#  'session': '4a5742f8a3e018651dbc628611618ab5a05cefee18dfedb09a5fafa99c42fa41',
#  'started_at': '2018-07-06T13:07:54.085Z',
#  'subject_dimensions': [{'clientHeight': 534,
#    'clientWidth': 640,
#    'naturalHeight': 534,
#    'naturalWidth': 640}],
#  'user_agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36',
#  'user_group_ids': [],
#  'user_language': 'en',
#  'utc_offset': '-7200',
#  'viewport': {'height': 962, 'width': 1503}}

# %%
annotations_5 = json.loads(csv.loc[5, 'annotations'])
annotations_5
# Out:
# [{'task': 'T1',
#   'task_label': 'draw all plastics',
#   'value': [{'details': [],
#     'frame': 0,
#     'height': 40.6932373046875,
#     'tool': 0,
#     'tool_label': 'plastic',
#     'width': 19.2757568359375,
#     'x': 1438.62548828125,
#     'y': 758.1796875},
#    {'details': [],
#     'frame': 0,
#     'height': 36.409759521484375,
#     'tool': 0,
#     'tool_label': 'plastic',
#     'width': 53.543701171875,
#     'x': 1361.5224609375,
#     'y': 432.63360595703125},
#    {'details': [],
#     'frame': 0,
#     'height': 40.693267822265625,
#     'tool': 0,
#     'tool_label': 'plastic',
#     'width': 29.9844970703125,
#     'x': 1286.5611572265625,
#     'y': 299.8450622558594},
#    {'details': [],
#     'frame': 0,
#     'height': 66.39422607421875,
#     'tool': 0,
#     'tool_label': 'plastic',
#     'width': 64.25251770019531,
#     'x': 70.046875,
#     'y': 717.4864501953125},
#    {'details': [],
#     'frame': 0,
#     'height': 107.0875244140625,
# ...

# %%
metadata_5 = json.loads(csv.loc[5, 'metadata'])
metadata_5
# Out:
# {'finished_at': '2018-07-06T17:52:11.589Z',
#  'live_project': False,
#  'session': 'bea9fb8e3a70d468a50c2d97a1b488c888465ed351961d34d7e54d3f54dc664f',
#  'started_at': '2018-07-06T17:50:57.689Z',
#  'subject_dimensions': [{'clientHeight': 504,
#    'clientWidth': 897,
#    'naturalHeight': 1080,
#    'naturalWidth': 1920}],
#  'user_agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36',
#  'user_language': 'en',
#  'utc_offset': '-7200',
#  'viewport': {'height': 856, 'width': 1443}}

# %%
subject_data_5 = json.loads(csv.loc[5, 'subject_data'])
subject_data_5
# Out:
# {'23401325': {'Filename': 'Grogol_Location_1_2018-05-02 10-00-00-05_cam6.jpg',
#   'retired': None}}

# %%
sub_5 = list(subject_data_5.values())

# %%
sub_5[0]['Filename']
# Out:
# 'Grogol_Location_1_2018-05-02 10-00-00-05_cam6.jpg'
